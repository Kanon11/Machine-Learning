# %%
from pandas import Series
from pandas import DataFrame
series = Series.from_csv('daily-minimum-temperatures-in-me.csv', header=0)
temps = DataFrame(series.values)
dataframe = DataFrame()
shifted = temps.shift(2)
window = shifted.rolling(window=2)
means = window.mean()
dataframe = pd.concat([means, temps], axis=1)
dataframe.columns = ['mean(t-2,t-1)', 't+1']
print(dataframe.head(5))
# Out:
# C:\Users\DELL\AppData\Roaming\Python\Python36\site-packages\pandas\core\series.py:2849: FutureWarning: from_csv is deprecated. Please use read_csv(...) instead. Note that some of the default arguments are different, so please refer to the documentation for from_csv when changing your function calls
#   infer_datetime_format=infer_datetime_format)
#   mean(t-2,t-1)   t+1
# 0           NaN  20.7
# 1           NaN  17.9
# 2          20.7  18.8
# 3          17.9  14.6
# 4          18.8  15.8

# %%
window
# Out:
# Rolling [window=2,center=False,axis=0]

# %%
series
# Out:
# Date
# 1981-01-01    20.7
# 1981-01-02    17.9
# 1981-01-03    18.8
# 1981-01-04    14.6
# 1981-01-05    15.8
# 1981-01-06    15.8
# 1981-01-07    15.8
# 1981-01-08    17.4
# 1981-01-09    21.8
# 1981-01-10      20
# 1981-01-11    16.2
# 1981-01-12    13.3
# 1981-01-13    16.7
# 1981-01-14    21.5
# 1981-01-15      25
# 1981-01-16    20.7
# 1981-01-17    20.6
# 1981-01-18    24.8
# 1981-01-19    17.7
# 1981-01-20    15.5
# 1981-01-21    18.2
# 1981-01-22    12.1
# 1981-01-23    14.4
# 1981-01-24      16
# 1981-01-25    16.5
# 1981-01-26    18.7
# 1981-01-27    19.4
# 1981-01-28    17.2
# 1981-01-29    15.5
# 1981-01-30    15.1
#               ...
# 1990-12-02    13.2
# 1990-12-03    16.2
# 1990-12-04    17.3
# 1990-12-05    20.5
# 1990-12-06    20.2
# 1990-12-07    19.4
# 1990-12-08    15.5
# 1990-12-09    14.1
# 1990-12-10      11
# 1990-12-11    11.1
# 1990-12-12      14
# 1990-12-13    11.4
# 1990-12-14    12.5
# 1990-12-15    13.4
# 1990-12-16    13.6
# 1990-12-17    13.9
# ...

# %%
import pandas as pd

# %%
df=pd.read_csv('daily-minimum-temperatures-in-me.csv')

# %%
df.columns
# Out:
# Index(['Date', 'Daily minimum temperatures in Melbourne, Australia, 1981-1990'], dtype='object')

# %%
df.rename(columns={'Daily minimum temperatures in Melbourne, Australia, 1981-1990':'Temperatures'},inplace=True)

# %%
df.head(60)
# Out:
#          Date Temperatures  month  day
# 0  1981-01-01         20.7      1    1
# 1  1981-01-02         17.9      1    2
# 2  1981-01-03         18.8      1    3
# 3  1981-01-04         14.6      1    4
# 4  1981-01-05         15.8      1    5
# 5  1981-01-06         15.8      1    6
# 6  1981-01-07         15.8      1    7
# 7  1981-01-08         17.4      1    8
# 8  1981-01-09         21.8      1    9
# 9  1981-01-10           20      1   10
# 10 1981-01-11         16.2      1   11
# 11 1981-01-12         13.3      1   12
# 12 1981-01-13         16.7      1   13
# 13 1981-01-14         21.5      1   14
# 14 1981-01-15           25      1   15
# 15 1981-01-16         20.7      1   16
# 16 1981-01-17         20.6      1   17
# 17 1981-01-18         24.8      1   18
# 18 1981-01-19         17.7      1   19
# 19 1981-01-20         15.5      1   20
# 20 1981-01-21         18.2      1   21
# 21 1981-01-22         12.1      1   22
# 22 1981-01-23         14.4      1   23
# ...

# %%
df.dtypes
# Out:
# Date            object
# Temperatures    object
# dtype: object

# %%
df.Date=pd.to_datetime(df.Date)

# %%
df.dtypes
# Out:
# Date            datetime64[ns]
# Temperatures            object
# dtype: object

# %%
df['month']=df.Date.dt.month

# %%
df['day']=df.Date.dt.day

# %%
df.drop(['Date'],axis=1,inplace=True)

# %%
df.head()
# Out:
#    month  day Temperatures
# 0      1    1         20.7
# 1      1    2         17.9
# 2      1    3         18.8
# 3      1    4         14.6
# 4      1    5         15.8

# %%
df=df[['month','day','Temperatures']]

# %%
df1=pd.concat([df.Temperatures.shift(1),df.Temperatures],axis=1)

# %%
df1.columns=['t-1','t+1']

# %%
df2.head(10)14.6
# Out:
#     t-3   t-2   t-1   t+1
# 0   NaN   NaN   NaN  20.7
# 1   NaN   NaN  20.7  17.9
# 2   NaN  20.7  17.9  18.8
# 3  20.7  17.9  18.8  14.6
# 4  17.9  18.8  14.6  15.8
# 5  18.8  14.6  15.8  15.8
# 6  14.6  15.8  15.8  15.8
# 7  15.8  15.8  15.8  17.4
# 8  15.8  15.8  17.4  21.8
# 9  15.8  17.4  21.8    20

# %%
df2=pd.concat([df.Temperatures.shift(3),df.Temperatures.shift(2),df.Temperatures.shift(1),df.Temperatures],axis=1)

# %%
df2.columns=['t-3','t-2','t-1','t+1']

# %%
window=df2.rolling(window=2)

# %%
means=window.mean()
means
# Out:
#        t-3   t-2   t-1   t+1
# 0      NaN   NaN   NaN  20.7
# 1      NaN   NaN  20.7  17.9
# 2      NaN  20.7  17.9  18.8
# 3     20.7  17.9  18.8  14.6
# 4     17.9  18.8  14.6  15.8
# 5     18.8  14.6  15.8  15.8
# 6     14.6  15.8  15.8  15.8
# 7     15.8  15.8  15.8  17.4
# 8     15.8  15.8  17.4  21.8
# 9     15.8  17.4  21.8    20
# 10    17.4  21.8    20  16.2
# 11    21.8    20  16.2  13.3
# 12      20  16.2  13.3  16.7
# 13    16.2  13.3  16.7  21.5
# 14    13.3  16.7  21.5    25
# 15    16.7  21.5    25  20.7
# 16    21.5    25  20.7  20.6
# 17      25  20.7  20.6  24.8
# 18    20.7  20.6  24.8  17.7
# 19    20.6  24.8  17.7  15.5
# 20    24.8  17.7  15.5  18.2
# 21    17.7  15.5  18.2  12.1
# 22    15.5  18.2  12.1  14.4
# 23    18.2  12.1  14.4    16
# 24    12.1  14.4    16  16.5
# 25    14.4    16  16.5  18.7
# 26      16  16.5  18.7  19.4
# 27    16.5  18.7  19.4  17.2
# 28    18.7  19.4  17.2  15.5
# 29    19.4  17.2  15.5  15.1
# ...    ...   ...   ...   ...
# ...

# %%
df3=pd.concat([means,df.Temperatures],axis=1)

# %%
df3.columns = ['mean(t-3,t-2,t-1,t+1)', 't+1']

# %%
df3.head(10)
# Out:
#   mean(t-3,t-2,t-1,t+1)   t+1
# 0                   NaN  20.7
# 1                  20.7  17.9
# 2                  17.9  18.8
# 3                  18.8  14.6
# 4                  14.6  15.8
# 5                  15.8  15.8
# 6                  15.8  15.8
# 7                  15.8  17.4
# 8                  17.4  21.8
# 9                  21.8    20
