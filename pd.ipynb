# %% [markdown]
# # How do I sort a pandas DataFrame or Series

# %%
import pandas as pd

# %%
movies=pd.read_csv('http://bit.ly/uforeports')

# %%
movies.head()
# Out:
#                    City Colors Reported Shape Reported State             Time
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00

# %%
# ai vabe sort korle dataframe a kono change ashe na.
movies['Time'].sort_values(ascending=False)
movies.head()
# Out:
#                    City Colors Reported Shape Reported State             Time
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00

# %%
# jodi dataframe a change ante chai tahole aivabe short korte hobe
ufo=movies.sort_values(['Time'])
ufo.tail()
# Out:
#                 City Colors Reported Shape Reported State           Time
# 17364  Mechanicsburg            BLUE       FIREBALL    PA  9/9/2000 3:00
# 17365    Coatesville             NaN          LIGHT    PA  9/9/2000 3:30
# 17366       Gardiner             NaN          LIGHT    MT  9/9/2000 3:30
# 17367   Mount Laurel             NaN       FIREBALL    NJ  9/9/2000 3:30
# 17368   Philadelphia             NaN        VARIOUS    PA  9/9/2000 3:30

# %%
Iris=pd.read_csv('Iris.csv')

# %%
Iris.columns
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
Iris_sort=Iris.sort_values(['SepalLengthCm'],ascending=False)
Iris_sort.head()
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 131  132            7.9           3.8            6.4           2.0
# 135  136            7.7           3.0            6.1           2.3
# 122  123            7.7           2.8            6.7           2.0
# 117  118            7.7           3.8            6.7           2.2
# 118  119            7.7           2.6            6.9           2.3
#
#             Species
# 131  Iris-virginica
# 135  Iris-virginica
# 122  Iris-virginica
# 117  Iris-virginica
# 118  Iris-virginica

# %% [markdown]
# # How do I filter rows of a pandas DataFrame by column value?

# %%
booleans=[]

# %%
movies = pd.read_csv('http://bit.ly/imdbratings')

# %%
movies.columns
# Out:
# Index(['star_rating', 'title', 'content_rating', 'genre', 'duration',
#        'actors_list'],
#       dtype='object')

# %%
for length in movies['duration']:
    if (length>=200):
        booleans.append(True)
    else:
        booleans.append(False)

# %%
is_long=pd.Series(booleans)

# %%
movies[is_long]
# Out:
#      star_rating                                          title  \
# 2            9.1                         The Godfather: Part II
# 7            8.9  The Lord of the Rings: The Return of the King
# 17           8.7                                  Seven Samurai
# 78           8.4                    Once Upon a Time in America
# 85           8.4                             Lawrence of Arabia
# 142          8.3              Lagaan: Once Upon a Time in India
# 157          8.2                             Gone with the Wind
# 204          8.1                                        Ben-Hur
# 445          7.9                           The Ten Commandments
# 476          7.8                                         Hamlet
# 630          7.7                                      Malcolm X
# 767          7.6                It's a Mad, Mad, Mad, Mad World
#
#     content_rating      genre  duration  \
# 2                R      Crime       200
# 7            PG-13  Adventure       201
# ...

# %%
is_long2=movies['duration']>=200

# %%
is_long2.head()
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# 4    False
# Name: duration, dtype: bool

# %%
movies[is_long2]
# Out:
#      star_rating                                          title  \
# 2            9.1                         The Godfather: Part II
# 7            8.9  The Lord of the Rings: The Return of the King
# 17           8.7                                  Seven Samurai
# 78           8.4                    Once Upon a Time in America
# 85           8.4                             Lawrence of Arabia
# 142          8.3              Lagaan: Once Upon a Time in India
# 157          8.2                             Gone with the Wind
# 204          8.1                                        Ben-Hur
# 445          7.9                           The Ten Commandments
# 476          7.8                                         Hamlet
# 630          7.7                                      Malcolm X
# 767          7.6                It's a Mad, Mad, Mad, Mad World
#
#     content_rating      genre  duration  \
# 2                R      Crime       200
# 7            PG-13  Adventure       201
# ...

# %%
movies[(movies['star_rating']>=9.0)&(movies['duration']>=200)&(movies['genre']=='Crime')]
# Out:
#    star_rating                   title content_rating  genre  duration  \
# 2          9.1  The Godfather: Part II              R  Crime       200
#
#                                          actors_list
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...

# %% [markdown]
# # How do I apply multiple filter Criteria to a pandas DataFrame?

# %%
movies[((movies['star_rating']>=8.0) & (movies['star_rating']<=9.0))]
# Out:
#      star_rating                                              title  \
# 3            9.0                                    The Dark Knight
# 4            8.9                                       Pulp Fiction
# 5            8.9                                       12 Angry Men
# 6            8.9                     The Good, the Bad and the Ugly
# 7            8.9      The Lord of the Rings: The Return of the King
# 8            8.9                                   Schindler's List
# 9            8.9                                         Fight Club
# 10           8.8  The Lord of the Rings: The Fellowship of the Ring
# 11           8.8                                          Inception
# 12           8.8     Star Wars: Episode V - The Empire Strikes Back
# 13           8.8                                       Forrest Gump
# 14           8.8              The Lord of the Rings: The Two Towers
# 15           8.7                                       Interstellar
# ...

# %% [markdown]
# # How do I read particular two columns from csv

# %%
ufo = pd.read_csv('http://bit.ly/uforeports',usecols=[0,1,2,3,4])

# %%
ufo.head()
# Out:
#                    City Colors Reported Shape Reported State             Time
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00

# %%
ufo['Address']= ufo['City']+', '+ufo['State']

# %%
ufo.head()
# Out:
#                    City Colors Reported Shape Reported State             Time  \
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00
#
#                     Address
# 0                Ithaca, NY
# 1           Willingboro, NJ
# 2               Holyoke, CO
# 3               Abilene, KS
# 4  New York Worlds Fair, NY

# %% [markdown]
# # Fastest Method to read csv from big file

# %%
ufo_3_rows=pd.read_csv('http://bit.ly/uforeports',nrows=3)

# %%
ufo_3_rows
# Out:
#           City  Colors Reported Shape Reported State             Time
# 0       Ithaca              NaN       TRIANGLE    NY   6/1/1930 22:00
# 1  Willingboro              NaN          OTHER    NJ  6/30/1930 20:00
# 2      Holyoke              NaN           OVAL    CO  2/15/1931 14:00

# %% [markdown]
# # Droping a columns from a pd dataframe

# %%
ufo_3_rows.drop(['Shape Reported','Colors Reported'],axis=1,inplace=True)

# %%
ufo_3_rows
# Out:
#           City State             Time
# 0       Ithaca    NY   6/1/1930 22:00
# 1  Willingboro    NJ  6/30/1930 20:00
# 2      Holyoke    CO  2/15/1931 14:00

# %%
ufo.head()
# Out:
#                    City Colors Reported Shape Reported State             Time  \
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00
#
#                     Address
# 0                Ithaca, NY
# 1           Willingboro, NJ
# 2               Holyoke, CO
# 3               Abilene, KS
# 4  New York Worlds Fair, NY

# %%
ufo.describe(include='all')
# Out:
#            City Colors Reported Shape Reported  State              Time  \
# count     18216            2882          15597  18241             18241
# unique     6476              27             27     52             16145
# top     Seattle             RED          LIGHT     CA  11/16/1999 19:00
# freq        187             780           2803   2529                27
#
#             Address
# count         18216
# unique         8029
# top     Seattle, WA
# freq            187

# %%
ufo.drop(index=[0,1],axis=0,inplace=True)

# %%
ufo.describe(include='all')
# Out:
#            City Colors Reported Shape Reported  State              Time  \
# count     18214            2882          15595  18239             18239
# unique     6476              27             27     52             16143
# top     Seattle             RED          LIGHT     CA  11/16/1999 19:00
# freq        187             780           2803   2529                27
#
#             Address
# count         18214
# unique         8029
# top     Seattle, WA
# freq            187

# %%
ufo.describe(include=['object','float64'],exclude=count)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-119-63996a66c729> in <module>()
# ----> 1 ufo.describe(include=['object','float64'],exclude=count)
#
# NameError: name 'count' is not defined

# %%
movies.describe()

# %%
movies.columns

# %%
movies.describe(exclude=['object'])

# %% [markdown]
# # what's the best way to drop every non_numeric columna for a DataFrame?

# %%
import numpy as np

# %%
X=movies.select_dtypes(include=[np.number]).dtypes

# %%
X.head()
# Out:
# star_rating    float64
# duration         int64
# dtype: object

# %%
movies.head()
