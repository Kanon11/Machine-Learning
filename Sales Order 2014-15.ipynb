# %%
import pandas as pd

# %%
dataframe=pd.read_csv('Sales Orders 2014-15.csv')

# %%
dataframe.head()
# Out:
#    customerid      orderdate salesordernumber  territoryid  productid  \
# 0       11217  1/3/2014 0:00          SO76869            1        771
# 1       11217  1/3/2014 0:00         SO297124            1        996
# 2       11217  1/3/2014 0:00         SO485914            1        957
# 3       11217  1/3/2014 0:00          SO76869            1        771
# 4       11217  1/3/2014 0:00         SO485914            1        885
#
#    unitprice  orderqty
# 0   2039.994         1
# 1     72.894         3
# 2   1430.442         4
# 3   2039.994         1
# 4    602.346         2

# %%
pd.set_option('display.max_rows',2000)
pd.set_option('display.max_colwidth',100)

# %%
dataframe.head()
# Out:
#    customerid      orderdate salesordernumber  territoryid  productid  \
# 0       11217  1/3/2014 0:00          SO76869            1        771
# 1       11217  1/3/2014 0:00         SO297124            1        996
# 2       11217  1/3/2014 0:00         SO485914            1        957
# 3       11217  1/3/2014 0:00          SO76869            1        771
# 4       11217  1/3/2014 0:00         SO485914            1        885
#
#    unitprice  orderqty
# 0   2039.994         1
# 1     72.894         3
# 2   1430.442         4
# 3   2039.994         1
# 4    602.346         2

# %%
dataframe.dtypes
# Out:
# customerid            int64
# orderdate            object
# salesordernumber     object
# territoryid           int64
# productid             int64
# unitprice           float64
# orderqty              int64
# dtype: object

# %%
dataframe['orderdate']=pd.to_datetime(dataframe.orderdate)

# %%
dataframe.orderdate.unique()
# Out:
# array(['2014-01-03T00:00:00.000000000', '2014-01-07T00:00:00.000000000',
#        '2014-01-08T00:00:00.000000000', '2014-01-09T00:00:00.000000000',
#        '2014-01-15T00:00:00.000000000', '2014-01-16T00:00:00.000000000',
#        '2014-01-17T00:00:00.000000000', '2014-01-19T00:00:00.000000000',
#        '2014-01-22T00:00:00.000000000', '2014-01-24T00:00:00.000000000',
#        '2014-01-25T00:00:00.000000000', '2014-01-26T00:00:00.000000000',
#        '2014-01-27T00:00:00.000000000', '2014-01-28T00:00:00.000000000',
#        '2014-01-30T00:00:00.000000000', '2014-02-03T00:00:00.000000000',
#        '2014-02-05T00:00:00.000000000', '2014-02-07T00:00:00.000000000',
#        '2014-02-09T00:00:00.000000000', '2014-02-12T00:00:00.000000000',
#        '2014-02-14T00:00:00.000000000', '2014-02-16T00:00:00.000000000',
#        '2014-02-17T00:00:00.000000000', '2014-02-21T00:00:00.000000000',
#        '2014-02-22T00:00:00.000000000', '2014-02-23T00:00:00.000000000',
# ...

# %%
dataframe
# Out:
#         customerid  orderdate salesordernumber  territoryid  productid  \
# 0            11217 2014-01-03          SO76869            1        771
# 1            11217 2014-01-03         SO297124            1        996
# 2            11217 2014-01-03         SO485914            1        957
# 3            11217 2014-01-03          SO76869            1        771
# 4            11217 2014-01-03         SO485914            1        885
# 5            11217 2014-01-03         SO202729            1        761
# 6            11217 2014-01-03         SO328589            1        877
# 7            11217 2014-01-03         SO108334            1        752
# 8            11217 2014-01-03         SO485914            1        954
# 9            11217 2014-01-03         SO171264            1        858
# 10           11217 2014-01-03         SO234194            1        708
# 11           11217 2014-01-03          SO76869            1        775
# ...

# %%
feature_cols=['']

# %%
dataframe['totalprice']=dataframe.unitprice*dataframe.orderqty
dataframe['dayofyear']=dataframe.orderdate.dt.dayofyear

# %%
dataframe.orderdate.max()
# Out:
# Timestamp('2016-01-01 00:00:00')

# %%
dataframe.orderdate.min()
# Out:
# Timestamp('2014-01-01 00:00:00')

# %%
dataframe.orderdate.max()-dataframe.orderdate.min()
# Out:
# Timedelta('730 days 00:00:00')

# %%
# %matplotlib inline
dataframe.customerid.value_counts(ascending=True)
# Out:
# 16905     26
# 17477     26
# 23808     26
# 23239     26
# 20374     26
# 23176     27
# 13337     27
# 20193     27
# 25418     27
# 14520     27
# 29015     27
# 21327     27
# 20296     27
# 18764     27
# 29004     27
# 22225     27
# 29160     27
# 27465     27
# 29057     27
# 20295     27
# 25411     27
# 21636     27
# 13861     27
# 11949     27
# 25359     27
# 17548     27
# 20274     27
# 11621     27
# 28994     27
# 26274     27
# 17557     27
# 28999     27
# 27639     27
# 18061     27
# 25840     27
# 14369     27
# 14589     28
# 20780     28
# 17564     28
# 17430     28
# 23207     28
# 16899     28
# 19245     28
# 19714     28
# 22250     28
# 13228     28
# 20195     28
# 13654     28
# 13169     28
# 13937     28
# 20124     28
# 28253     28
# 11940     28
# 20653     28
# 17434     28
# 23786     28
# 15858     28
# 23191     28
# 26586     28
# 23594     28
# 22164     28
# 24774     28
# 12068     28
# 15772     28
# 23276     28
# 27030     28
# ...

# %%
dataframe.isnull().sum()
# Out:
# customerid          0
# orderdate           0
# salesordernumber    0
# territoryid         0
# productid           0
# unitprice           0
# orderqty            0
# totalprice          0
# dayofyear           0
# dtype: int64

# %%
dataframe.shape
# Out:
# (270817, 9)

# %%
# alada alada user id ase koita ta check korte chai
dataframe.customerid.unique()
# Out:
# array([11217, 29334, 29335, ..., 13099, 11533, 30081], dtype=int64)

# %%
dataframe.columns
# Out:
# Index(['customerid', 'orderdate', 'salesordernumber', 'territoryid',
#        'productid', 'unitprice', 'orderqty', 'totalprice', 'dayofyear'],
#       dtype='object')

# %%
feature_cols=['customerid','dayofyear','territoryid','productid','unitprice','orderqty']

# %%
X=dataframe[feature_cols]

# %%
y=dataframe.totalprice

# %%
X.head()
# Out:
#    customerid  dayofyear  territoryid  productid  unitprice  orderqty
# 0       11217          3            1        771   2039.994         1
# 1       11217          3            1        996     72.894         3
# 2       11217          3            1        957   1430.442         4
# 3       11217          3            1        771   2039.994         1
# 4       11217          3            1        885    602.346         2

# %%
from sklearn.metrics import confusion_matrix

# %%
from sklearn.metrics import accuracy_score

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
from sklearn import model_selection

# %%
validation_size = 0.20
seed = 7

# %%
X_train, X_test, y_train, y_test = model_selection.train_test_split(X, y, test_size=validation_size, random_state=seed)

# %%
X_train.values
# Out:
# array([[  1.16580000e+04,   3.52000000e+02,   4.00000000e+00,
#           7.63000000e+02,   4.69794000e+02,   3.00000000e+00],
#        [  2.99300000e+04,   8.30000000e+01,   3.00000000e+00,
#           8.71000000e+02,   9.99000000e+00,   1.00000000e+00],
#        [  3.00110000e+04,   1.75000000e+02,   5.00000000e+00,
#           7.25000000e+02,   2.02332000e+02,   4.00000000e+00],
#        ...,
#        [  1.24390000e+04,   2.31000000e+02,   1.00000000e+00,
#           8.81000000e+02,   5.39900000e+01,   1.00000000e+00],
#        [  1.84240000e+04,   2.14000000e+02,   4.00000000e+00,
#           9.25000000e+02,   1.49874000e+02,   4.00000000e+00],
#        [  3.01120000e+04,   2.67000000e+02,   1.00000000e+00,
#           8.70000000e+02,   4.99000000e+00,   1.00000000e+00]])

# %%
y_train.values
# Out:
# array([ 1409.382,     9.99 ,   809.328, ...,    53.99 ,   599.496,     4.99 ])

# %%
from pandas.tools.plotting import scatter_matrix
import matplotlib.pyplot as plt
from sklearn import model_selection
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC

# %%
models=[]
models.append(('LR', LogisticRegression()))

# evaluate each model in turn
results = []
names = []
for name, model in models:
    kfold = model_selection.KFold(n_splits=10, random_state=seed)
    cv_results = model_selection.cross_val_score(model, X_train, y_train, cv=kfold)
    results.append(cv_results)
    names.append(name)
    msg = "%s: %f (%f)" % (name, cv_results.mean(), cv_results.std())
    print(msg)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-66-4632d4d300b2> in <module>()
#       7 for name, model in models:
#       8     kfold = model_selection.KFold(n_splits=10, random_state=seed)
# ----> 9     cv_results = model_selection.cross_val_score(model, X_train, y_train, cv=kfold)
#      10     results.append(cv_results)
#      11     names.append(name)
#
# ~\AppData\Roaming\Python\Python36\site-packages\sklearn\model_selection\_validation.py in cross_val_score(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, pre_dispatch)
#     340                                 n_jobs=n_jobs, verbose=verbose,
#     341                                 fit_params=fit_params,
# --> 342                                 pre_dispatch=pre_dispatch)
#     343     return cv_results['test_score']
#     344
#
# ...
